# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import gmaps

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ac6034d69b61fbae02a912e1760b5174

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ac6034d69b61fbae02a912e1760b5174&q=Boston

# %%
# Create an empty list to hold the weather data.

city_data = []

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | mitsamiouli
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | port lincoln
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | teya
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | padang
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | haines junction
# Processing Record 18 of Set 1 | cabedelo
# Processing Record 19 of Set 1 | brasilia de minas
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | stokmarknes
# Processing Record 22 of Set 1 | barstow
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | alta floresta
# Processing Record 25 of Set 1 | hakvik
# City not found. Skipping...
# Processing Record 26 of Set 1 | defiance
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | stornoway
# Processing Record 29 of Set 1 | bengkulu
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | lasa
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | tornio
# Processing Record 37 of Set 1 | san cristobal
# Processing Record 38 of Set 1 | ende
# Processing Record 39 of Set 1 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | te anau
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | berlevag
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | mirina
# City not found. Skipping...
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | conde
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | gazojak
# Processing Record 4 of Set 2 | hambantota
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | tuktoyaktuk
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | chimbote
# Processing Record 9 of Set 2 | sao felix do xingu
# Processing Record 10 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | mosquera
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | vizinga
# Processing Record 17 of Set 2 | bereda
# Processing Record 18 of Set 2 | makat
# Processing Record 19 of Set 2 | yulara
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | panguna
# Processing Record 22 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 23 of Set 2 | vitry-le-francois
# Processing Record 24 of Set 2 | kristiansund
# Processing Record 25 of Set 2 | pahrump
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | ahipara
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | constantine
# Processing Record 31 of Set 2 | nikolayevsk-na-amure
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | la maddalena
# Processing Record 35 of Set 2 | maniitsoq
# Processing Record 36 of Set 2 | eyl
# Processing Record 37 of Set 2 | strezhevoy
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | ust-kuyga
# Processing Record 40 of Set 2 | bukachacha
# Processing Record 41 of Set 2 | dudinka
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | katherine
# Processing Record 46 of Set 2 | tomatlan
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | port hedland
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | mamontovo
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | ossora
# Processing Record 5 of Set 3 | muroto
# Processing Record 6 of Set 3 | novobirilyussy
# Processing Record 7 of Set 3 | pisco
# Processing Record 8 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 3 | vanavara
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | tukrah
# Processing Record 13 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 3 | ostersund
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | hope
# Processing Record 17 of Set 3 | nantucket
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | tarbagatay
# Processing Record 21 of Set 3 | tautira
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | ruidoso
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | pacific grove
# Processing Record 27 of Set 3 | salihorsk
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | lucapa
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | goderich
# Processing Record 32 of Set 3 | dunedin
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | penzance
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | santa isabel
# Processing Record 41 of Set 3 | baghdad
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | buraydah
# Processing Record 44 of Set 3 | kamiiso
# Processing Record 45 of Set 3 | evensk
# Processing Record 46 of Set 3 | anloga
# Processing Record 47 of Set 3 | muswellbrook
# Processing Record 48 of Set 3 | dungarvan
# Processing Record 49 of Set 3 | vostok
# Processing Record 50 of Set 3 | konya
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | turan
# Processing Record 3 of Set 4 | salalah
# Processing Record 4 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | leningradskiy
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | taoudenni
# Processing Record 9 of Set 4 | laguna
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | nemuro
# Processing Record 12 of Set 4 | zermatt
# Processing Record 13 of Set 4 | baruun-urt
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | camacupa
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | maltahohe
# Processing Record 18 of Set 4 | slave lake
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | ust-maya
# Processing Record 21 of Set 4 | akwatia
# Processing Record 22 of Set 4 | palmer
# Processing Record 23 of Set 4 | sydney
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | avera
# Processing Record 26 of Set 4 | nenita
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | richards bay
# Processing Record 30 of Set 4 | pombas
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | yeppoon
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | chuy
# Processing Record 35 of Set 4 | henties bay
# Processing Record 36 of Set 4 | foumban
# Processing Record 37 of Set 4 | ingham
# Processing Record 38 of Set 4 | santa cruz
# Processing Record 39 of Set 4 | samandag
# Processing Record 40 of Set 4 | chorbog
# City not found. Skipping...
# Processing Record 41 of Set 4 | douentza
# Processing Record 42 of Set 4 | havoysund
# Processing Record 43 of Set 4 | lisakovsk
# Processing Record 44 of Set 4 | irbil
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | konosha
# Processing Record 47 of Set 4 | kilindoni
# Processing Record 48 of Set 4 | luganville
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | verkhnevilyuysk
# Processing Record 2 of Set 5 | vittorio veneto
# Processing Record 3 of Set 5 | rognan
# Processing Record 4 of Set 5 | rocha
# Processing Record 5 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 5 | gubkinskiy
# Processing Record 7 of Set 5 | paamiut
# Processing Record 8 of Set 5 | juneau
# Processing Record 9 of Set 5 | saint-francois
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | gasa
# Processing Record 12 of Set 5 | san jose
# Processing Record 13 of Set 5 | hervey bay
# Processing Record 14 of Set 5 | pevek
# Processing Record 15 of Set 5 | katsuura
# Processing Record 16 of Set 5 | batagay-alyta
# Processing Record 17 of Set 5 | deputatskiy
# Processing Record 18 of Set 5 | presidencia roque saenz pena
# Processing Record 19 of Set 5 | boden
# Processing Record 20 of Set 5 | wukari
# Processing Record 21 of Set 5 | tessalit
# Processing Record 22 of Set 5 | oshikango
# Processing Record 23 of Set 5 | tashtyp
# Processing Record 24 of Set 5 | boa vista
# Processing Record 25 of Set 5 | namibe
# Processing Record 26 of Set 5 | xining
# Processing Record 27 of Set 5 | westport
# Processing Record 28 of Set 5 | avarua
# Processing Record 29 of Set 5 | la cruz
# Processing Record 30 of Set 5 | wete
# Processing Record 31 of Set 5 | kurilsk
# Processing Record 32 of Set 5 | doka
# Processing Record 33 of Set 5 | zyryanka
# Processing Record 34 of Set 5 | andros town
# Processing Record 35 of Set 5 | oregon city
# Processing Record 36 of Set 5 | torbay
# Processing Record 37 of Set 5 | vila franca do campo
# Processing Record 38 of Set 5 | hilo
# Processing Record 39 of Set 5 | nishihara
# Processing Record 40 of Set 5 | takoradi
# Processing Record 41 of Set 5 | pitea
# Processing Record 42 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint-pierre
# Processing Record 44 of Set 5 | bahraich
# Processing Record 45 of Set 5 | shakawe
# Processing Record 46 of Set 5 | manavgat
# Processing Record 47 of Set 5 | alekseyevka
# Processing Record 48 of Set 5 | marzuq
# Processing Record 49 of Set 5 | buchanan
# Processing Record 50 of Set 5 | shwebo
# Processing Record 1 of Set 6 | plettenberg bay
# Processing Record 2 of Set 6 | kaili
# Processing Record 3 of Set 6 | redlands
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | sao gabriel da cachoeira
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 6 | andenes
# Processing Record 11 of Set 6 | kerouane
# Processing Record 12 of Set 6 | marsa matruh
# Processing Record 13 of Set 6 | thayetmyo
# Processing Record 14 of Set 6 | coquimbo
# Processing Record 15 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 6 | aldan
# Processing Record 17 of Set 6 | kloulklubed
# Processing Record 18 of Set 6 | nanortalik
# Processing Record 19 of Set 6 | qaqortoq
# Processing Record 20 of Set 6 | fountain
# Processing Record 21 of Set 6 | shenjiamen
# Processing Record 22 of Set 6 | labrea
# Processing Record 23 of Set 6 | canalete
# Processing Record 24 of Set 6 | port elizabeth
# Processing Record 25 of Set 6 | bay roberts
# Processing Record 26 of Set 6 | kpandu
# Processing Record 27 of Set 6 | dossor
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | kotaparh
# Processing Record 30 of Set 6 | adeje
# Processing Record 31 of Set 6 | devaprayag
# Processing Record 32 of Set 6 | camabatela
# Processing Record 33 of Set 6 | lindi
# Processing Record 34 of Set 6 | trapani
# Processing Record 35 of Set 6 | saint-augustin
# Processing Record 36 of Set 6 | sri aman
# Processing Record 37 of Set 6 | bonanza
# Processing Record 38 of Set 6 | kolyubakino
# Processing Record 39 of Set 6 | dalianwan
# Processing Record 40 of Set 6 | egvekinot
# Processing Record 41 of Set 6 | itaituba
# Processing Record 42 of Set 6 | naze
# Processing Record 43 of Set 6 | coroico
# Processing Record 44 of Set 6 | piracuruca
# Processing Record 45 of Set 6 | bakonyszentlaszlo
# Processing Record 46 of Set 6 | el alto
# Processing Record 47 of Set 6 | marquette
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | syracuse
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | abalak
# Processing Record 2 of Set 7 | bako
# Processing Record 3 of Set 7 | abha
# Processing Record 4 of Set 7 | parsabad
# Processing Record 5 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 7 | carnarvon
# Processing Record 7 of Set 7 | koksovyy
# Processing Record 8 of Set 7 | goksun
# Processing Record 9 of Set 7 | nurota
# Processing Record 10 of Set 7 | mareeba
# Processing Record 11 of Set 7 | lagoa
# Processing Record 12 of Set 7 | pilar
# Processing Record 13 of Set 7 | iralaya
# Processing Record 14 of Set 7 | manuk mangkaw
# Processing Record 15 of Set 7 | kamyshevatskaya
# Processing Record 16 of Set 7 | prince rupert
# Processing Record 17 of Set 7 | safaga
# Processing Record 18 of Set 7 | oistins
# Processing Record 19 of Set 7 | trondheim
# Processing Record 20 of Set 7 | spearfish
# Processing Record 21 of Set 7 | bundaberg
# Processing Record 22 of Set 7 | arlit
# Processing Record 23 of Set 7 | amalapuram
# Processing Record 24 of Set 7 | forest grove
# Processing Record 25 of Set 7 | mayo
# Processing Record 26 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | vilhena
# Processing Record 29 of Set 7 | great yarmouth
# Processing Record 30 of Set 7 | san policarpo
# Processing Record 31 of Set 7 | khatanga
# Processing Record 32 of Set 7 | varkaus
# Processing Record 33 of Set 7 | awbari
# Processing Record 34 of Set 7 | kaitangata
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | marivan
# Processing Record 37 of Set 7 | cachipay
# Processing Record 38 of Set 7 | san andres
# Processing Record 39 of Set 7 | tatarsk
# Processing Record 40 of Set 7 | kamaishi
# Processing Record 41 of Set 7 | vitimskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | noumea
# Processing Record 43 of Set 7 | mehamn
# Processing Record 44 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 7 | sandwick
# Processing Record 46 of Set 7 | awjilah
# Processing Record 47 of Set 7 | mananara
# Processing Record 48 of Set 7 | lerwick
# Processing Record 49 of Set 7 | ilhabela
# Processing Record 50 of Set 7 | kharan
# Processing Record 1 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 8 | versalles
# Processing Record 3 of Set 8 | olafsvik
# Processing Record 4 of Set 8 | kieta
# Processing Record 5 of Set 8 | iberia
# Processing Record 6 of Set 8 | sassandra
# Processing Record 7 of Set 8 | brae
# Processing Record 8 of Set 8 | half moon bay
# Processing Record 9 of Set 8 | hofn
# Processing Record 10 of Set 8 | vao
# Processing Record 11 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 8 | aberdeen
# Processing Record 13 of Set 8 | sungaipenuh
# Processing Record 14 of Set 8 | aspindza
# Processing Record 15 of Set 8 | ambilobe
# Processing Record 16 of Set 8 | kilrush
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | shebunino
# Processing Record 19 of Set 8 | souillac
# Processing Record 20 of Set 8 | deerlijk
# Processing Record 21 of Set 8 | mantua
# Processing Record 22 of Set 8 | gurlan
# Processing Record 23 of Set 8 | rawson
# Processing Record 24 of Set 8 | beringovskiy
# Processing Record 25 of Set 8 | iqaluit
# Processing Record 26 of Set 8 | komsomolskiy
# Processing Record 27 of Set 8 | la peca
# Processing Record 28 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 8 | meulaboh
# Processing Record 30 of Set 8 | nelson bay
# Processing Record 31 of Set 8 | tazovskiy
# Processing Record 32 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 8 | sinnamary
# Processing Record 34 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 8 | kawalu
# Processing Record 36 of Set 8 | carepa
# Processing Record 37 of Set 8 | jalu
# Processing Record 38 of Set 8 | lufkin
# Processing Record 39 of Set 8 | luderitz
# Processing Record 40 of Set 8 | eldorado
# Processing Record 41 of Set 8 | zhigansk
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | thinadhoo
# Processing Record 44 of Set 8 | belmonte
# Processing Record 45 of Set 8 | whitley bay
# Processing Record 46 of Set 8 | sorland
# Processing Record 47 of Set 8 | tiksi
# Processing Record 48 of Set 8 | houlung
# City not found. Skipping...
# Processing Record 49 of Set 8 | oranjestad
# Processing Record 50 of Set 8 | karksi-nuia
# Processing Record 1 of Set 9 | shimoda
# Processing Record 2 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 9 | panjab
# Processing Record 4 of Set 9 | togur
# Processing Record 5 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 9 | bonavista
# Processing Record 7 of Set 9 | san juan del sur
# Processing Record 8 of Set 9 | lockhart
# Processing Record 9 of Set 9 | yar-sale
# Processing Record 10 of Set 9 | korla
# Processing Record 11 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 9 | kamenskiy
# Processing Record 13 of Set 9 | sistranda
# Processing Record 14 of Set 9 | taltal
# Processing Record 15 of Set 9 | clarksburg
# Processing Record 16 of Set 9 | tucuman
# Processing Record 17 of Set 9 | hasaki
# Processing Record 18 of Set 9 | mahebourg
# Processing Record 19 of Set 9 | miles city
# Processing Record 20 of Set 9 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 21 of Set 9 | volodarskiy
# Processing Record 22 of Set 9 | asau
# Processing Record 23 of Set 9 | monterrey
# Processing Record 24 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 25 of Set 9 | lisieux
# Processing Record 26 of Set 9 | honiara
# Processing Record 27 of Set 9 | jinchang
# Processing Record 28 of Set 9 | kiama
# Processing Record 29 of Set 9 | satana
# Processing Record 30 of Set 9 | diego de almagro
# Processing Record 31 of Set 9 | damietta
# Processing Record 32 of Set 9 | bandarbeyla
# Processing Record 33 of Set 9 | doha
# Processing Record 34 of Set 9 | ilulissat
# Processing Record 35 of Set 9 | sola
# Processing Record 36 of Set 9 | gigmoto
# Processing Record 37 of Set 9 | aktau
# Processing Record 38 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 9 | turek
# Processing Record 41 of Set 9 | margate
# Processing Record 42 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 9 | manta
# Processing Record 44 of Set 9 | grand gaube
# Processing Record 45 of Set 9 | kapuskasing
# Processing Record 46 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 47 of Set 9 | roebourne
# Processing Record 48 of Set 9 | weston
# Processing Record 49 of Set 9 | mzimba
# Processing Record 50 of Set 9 | mnogovershinnyy
# Processing Record 1 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 10 | husavik
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | inirida
# Processing Record 5 of Set 10 | jitra
# Processing Record 6 of Set 10 | chajul
# Processing Record 7 of Set 10 | anadyr
# Processing Record 8 of Set 10 | dakar
# Processing Record 9 of Set 10 | lavrentiya
# Processing Record 10 of Set 10 | bela
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | ola
# Processing Record 13 of Set 10 | paita
# Processing Record 14 of Set 10 | gulu
# Processing Record 15 of Set 10 | bam
# Processing Record 16 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 17 of Set 10 | traverse city
# Processing Record 18 of Set 10 | seydi
# Processing Record 19 of Set 10 | rio gallegos
# Processing Record 20 of Set 10 | broken hill
# Processing Record 21 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 10 | asyut
# Processing Record 23 of Set 10 | gimli
# Processing Record 24 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 10 | chicama
# Processing Record 26 of Set 10 | vaitape
# Processing Record 27 of Set 10 | yerbogachen
# Processing Record 28 of Set 10 | clarence town
# Processing Record 29 of Set 10 | san vicente
# Processing Record 30 of Set 10 | riviera beach
# Processing Record 31 of Set 10 | yangambi
# Processing Record 32 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 33 of Set 10 | ewo
# Processing Record 34 of Set 10 | hoopstad
# Processing Record 35 of Set 10 | matamoros
# Processing Record 36 of Set 10 | hualmay
# Processing Record 37 of Set 10 | illapel
# Processing Record 38 of Set 10 | gamba
# Processing Record 39 of Set 10 | katghora
# Processing Record 40 of Set 10 | turayf
# Processing Record 41 of Set 10 | fare
# Processing Record 42 of Set 10 | milkovo
# Processing Record 43 of Set 10 | trincomalee
# Processing Record 44 of Set 10 | deder
# Processing Record 45 of Set 10 | tongren
# Processing Record 46 of Set 10 | warmbad
# Processing Record 47 of Set 10 | wasilla
# Processing Record 48 of Set 10 | carutapera
# Processing Record 49 of Set 10 | gornyak
# Processing Record 50 of Set 10 | constitucion
# Processing Record 1 of Set 11 | mananjary
# Processing Record 2 of Set 11 | nefteyugansk
# Processing Record 3 of Set 11 | aitape
# Processing Record 4 of Set 11 | requena
# Processing Record 5 of Set 11 | zirandaro
# Processing Record 6 of Set 11 | malazgirt
# Processing Record 7 of Set 11 | aykhal
# Processing Record 8 of Set 11 | touros
# Processing Record 9 of Set 11 | iquique
# Processing Record 10 of Set 11 | tarboro
# Processing Record 11 of Set 11 | cabra
# Processing Record 12 of Set 11 | baykit
# Processing Record 13 of Set 11 | sioux lookout
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 11 | reconquista
# Processing Record 17 of Set 11 | phitsanulok
# Processing Record 18 of Set 11 | buenos aires
# Processing Record 19 of Set 11 | nargana
# Processing Record 20 of Set 11 | abu dhabi
# Processing Record 21 of Set 11 | kushiro
# Processing Record 22 of Set 11 | yarkovo
# Processing Record 23 of Set 11 | batagay
# Processing Record 24 of Set 11 | cayenne
# Processing Record 25 of Set 11 | acarau
# Processing Record 26 of Set 11 | vagur
# Processing Record 27 of Set 11 | kuminskiy
# Processing Record 28 of Set 11 | pimentel
# Processing Record 29 of Set 11 | naugarzan
# City not found. Skipping...
# Processing Record 30 of Set 11 | kangaatsiaq
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | itoman
# Processing Record 33 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 34 of Set 11 | phalaborwa
# Processing Record 35 of Set 11 | agadez
# Processing Record 36 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 11 | srednekolymsk
# Processing Record 38 of Set 11 | healdsburg
# Processing Record 39 of Set 11 | rio grande
# Processing Record 40 of Set 11 | selkirk
# Processing Record 41 of Set 11 | sale
# Processing Record 42 of Set 11 | swan river
# Processing Record 43 of Set 11 | port blair
# Processing Record 44 of Set 11 | beni
# Processing Record 45 of Set 11 | sept-iles
# Processing Record 46 of Set 11 | redcliffe
# Processing Record 47 of Set 11 | tymovskoye
# Processing Record 48 of Set 11 | chibuto
# Processing Record 49 of Set 11 | rio bananal
# Processing Record 50 of Set 11 | benjamin hill
# Processing Record 1 of Set 12 | sakaiminato
# Processing Record 2 of Set 12 | maragogi
# Processing Record 3 of Set 12 | lac du bonnet
# Processing Record 4 of Set 12 | simga
# Processing Record 5 of Set 12 | montagnana
# Processing Record 6 of Set 12 | sambava
# Processing Record 7 of Set 12 | aklavik
# Processing Record 8 of Set 12 | gilbert
# Processing Record 9 of Set 12 | port shepstone
# Processing Record 10 of Set 12 | atasu
# Processing Record 11 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 12 | rapar
# Processing Record 13 of Set 12 | smidovich
# Processing Record 14 of Set 12 | tambopata
# Processing Record 15 of Set 12 | elizabeth city
# Processing Record 16 of Set 12 | soe
# Processing Record 17 of Set 12 | la ronge
# Processing Record 18 of Set 12 | mount gambier
# Processing Record 19 of Set 12 | san ramon
# Processing Record 20 of Set 12 | ntungamo
# Processing Record 21 of Set 12 | mehriz
# Processing Record 22 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 12 | freeport
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | williams lake
# Processing Record 26 of Set 12 | puerto escondido
# Processing Record 27 of Set 12 | bilibino
# Processing Record 28 of Set 12 | arroyo
# Processing Record 29 of Set 12 | nome
# Processing Record 30 of Set 12 | urumqi
# Processing Record 31 of Set 12 | champerico
# Processing Record 32 of Set 12 | acari
# Processing Record 33 of Set 12 | kumano
# Processing Record 34 of Set 12 | tantoyuca
# Processing Record 35 of Set 12 | palauig
# Processing Record 36 of Set 12 | ballina
# Processing Record 37 of Set 12 | arman
# Processing Record 38 of Set 12 | gondar
# Processing Record 39 of Set 12 | fukue
# Processing Record 40 of Set 12 | tilichiki
# Processing Record 41 of Set 12 | villa union
# Processing Record 42 of Set 12 | cap-aux-meules
# Processing Record 43 of Set 12 | mayuge
# Processing Record 44 of Set 12 | kiunga
# Processing Record 45 of Set 12 | kenai
# Processing Record 46 of Set 12 | teahupoo
# Processing Record 47 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 48 of Set 12 | litovko
# Processing Record 49 of Set 12 | ilembula
# Processing Record 50 of Set 12 | coihaique
# Processing Record 1 of Set 13 | comodoro rivadavia
# Processing Record 2 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 13 | priekule
# Processing Record 4 of Set 13 | umea
# Processing Record 5 of Set 13 | baripada
# Processing Record 6 of Set 13 | tocache
# Processing Record 7 of Set 13 | acapulco
# Processing Record 8 of Set 13 | turukhansk
# Processing Record 9 of Set 13 | havelock
# Processing Record 10 of Set 13 | luanda
# Processing Record 11 of Set 13 | nago
# Processing Record 12 of Set 13 | faanui
# Processing Record 13 of Set 13 | clonakilty
# Processing Record 14 of Set 13 | baindur
# Processing Record 15 of Set 13 | gazli
# Processing Record 16 of Set 13 | imbituba
# Processing Record 17 of Set 13 | chapais
# Processing Record 18 of Set 13 | kayerkan
# Processing Record 19 of Set 13 | campos altos
# Processing Record 20 of Set 13 | skoghall
# Processing Record 21 of Set 13 | pangnirtung
# Processing Record 22 of Set 13 | norrtalje
# Processing Record 23 of Set 13 | guerrero negro
# Processing Record 24 of Set 13 | ilula
# Processing Record 25 of Set 13 | dhanera
# Processing Record 26 of Set 13 | vardo
# Processing Record 27 of Set 13 | verkhnetulomskiy
# Processing Record 28 of Set 13 | limbang
# Processing Record 29 of Set 13 | san rafael del sur
# Processing Record 30 of Set 13 | rincon
# Processing Record 31 of Set 13 | rafai
# Processing Record 32 of Set 13 | sosnovo-ozerskoye
# Processing Record 33 of Set 13 | northam
# Processing Record 34 of Set 13 | pankrushikha
# Processing Record 35 of Set 13 | emerald
# Processing Record 36 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 37 of Set 13 | seoni malwa
# Processing Record 38 of Set 13 | portland
# Processing Record 39 of Set 13 | bani walid
# Processing Record 40 of Set 13 | ouallam
# Processing Record 41 of Set 13 | wanaka
# Processing Record 42 of Set 13 | manggar
# Processing Record 43 of Set 13 | salinopolis
# Processing Record 44 of Set 13 | broome
# Processing Record 45 of Set 13 | piacabucu
# Processing Record 46 of Set 13 | sao joao da barra
# Processing Record 47 of Set 13 | elmira
# Processing Record 48 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 49 of Set 13 | shache
# Processing Record 50 of Set 13 | beterou
# Processing Record 1 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 14 | matagami
# Processing Record 3 of Set 14 | aasiaat
# Processing Record 4 of Set 14 | horta
# Processing Record 5 of Set 14 | norilsk
# Processing Record 6 of Set 14 | quatre cocos
# Processing Record 7 of Set 14 | sitka
# Processing Record 8 of Set 14 | jumla
# Processing Record 9 of Set 14 | nola
# Processing Record 10 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 11 of Set 14 | kununurra
# Processing Record 12 of Set 14 | lingao
# Processing Record 13 of Set 14 | giyani
# Processing Record 14 of Set 14 | esna
# Processing Record 15 of Set 14 | dharchula
# Processing Record 16 of Set 14 | meiganga
# Processing Record 17 of Set 14 | barabai
# Processing Record 18 of Set 14 | mendi
# Processing Record 19 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 14 | denton
# Processing Record 21 of Set 14 | nalut
# Processing Record 22 of Set 14 | bethanien
# Processing Record 23 of Set 14 | belaya gora
# Processing Record 24 of Set 14 | high prairie
# Processing Record 25 of Set 14 | mount isa
# Processing Record 26 of Set 14 | aligudarz
# Processing Record 27 of Set 14 | cassilandia
# Processing Record 28 of Set 14 | hami
# Processing Record 29 of Set 14 | vigrestad
# Processing Record 30 of Set 14 | quime
# Processing Record 31 of Set 14 | tianpeng
# Processing Record 32 of Set 14 | kitob
# Processing Record 33 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 14 | grand forks
# Processing Record 35 of Set 14 | hirara
# Processing Record 36 of Set 14 | cadillac
# Processing Record 37 of Set 14 | harper
# Processing Record 38 of Set 14 | shalakusha
# Processing Record 39 of Set 14 | akyab
# Processing Record 40 of Set 14 | bubaque
# Processing Record 41 of Set 14 | ostrovnoy
# Processing Record 42 of Set 14 | shingu
# Processing Record 43 of Set 14 | ganzhou
# Processing Record 44 of Set 14 | banyo
# Processing Record 45 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 14 | khasan
# Processing Record 47 of Set 14 | abu samrah
# Processing Record 48 of Set 14 | beloha
# Processing Record 49 of Set 14 | tucuma
# Processing Record 50 of Set 14 | tamandare
# Processing Record 1 of Set 15 | weymouth
# Processing Record 2 of Set 15 | san carlos
# Processing Record 3 of Set 15 | rioja
# Processing Record 4 of Set 15 | narkevychi
# Processing Record 5 of Set 15 | biak
# Processing Record 6 of Set 15 | kargil
# Processing Record 7 of Set 15 | general pico
# Processing Record 8 of Set 15 | kholtoson
# Processing Record 9 of Set 15 | talnakh
# Processing Record 10 of Set 15 | burica
# City not found. Skipping...
# Processing Record 11 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 15 | namanyere
# Processing Record 13 of Set 15 | bud
# Processing Record 14 of Set 15 | cocal
# Processing Record 15 of Set 15 | batticaloa
# Processing Record 16 of Set 15 | whitecourt
# Processing Record 17 of Set 15 | jizan
# Processing Record 18 of Set 15 | banjar
# Processing Record 19 of Set 15 | ziro
# Processing Record 20 of Set 15 | qasigiannguit
# Processing Record 21 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 15 | osmena
# Processing Record 23 of Set 15 | endicott
# Processing Record 24 of Set 15 | jhawarian
# Processing Record 25 of Set 15 | manaure
# Processing Record 26 of Set 15 | ramasukha
# City not found. Skipping...
# Processing Record 27 of Set 15 | mandiana
# Processing Record 28 of Set 15 | tupik
# Processing Record 29 of Set 15 | ankazoabo
# Processing Record 30 of Set 15 | kidal
# Processing Record 31 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 32 of Set 15 | kahului
# Processing Record 33 of Set 15 | tigzirt
# Processing Record 34 of Set 15 | yamada
# Processing Record 35 of Set 15 | celestun
# Processing Record 36 of Set 15 | qrendi
# Processing Record 37 of Set 15 | launceston
# Processing Record 38 of Set 15 | ternate
# Processing Record 39 of Set 15 | dunmore east
# Processing Record 40 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 15 | san carlos de bariloche
# Processing Record 42 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 43 of Set 15 | khandyga
# Processing Record 44 of Set 15 | zeya
# Processing Record 45 of Set 15 | dubbo
# Processing Record 46 of Set 15 | vestmanna
# Processing Record 47 of Set 15 | sala
# Processing Record 48 of Set 15 | amahai
# Processing Record 49 of Set 15 | sibolga
# Processing Record 50 of Set 15 | yoichi
# Processing Record 1 of Set 16 | koslan
# Processing Record 2 of Set 16 | nuuk
# Processing Record 3 of Set 16 | pandan
# Processing Record 4 of Set 16 | atakpame
# Processing Record 5 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 6 of Set 16 | mandalgovi
# Processing Record 7 of Set 16 | roquetas de mar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Mitsamiouli      KM -11.3847   43.2844     79.72        80         100
# 1     Upernavik      GL  72.7868  -56.1549     -0.18        99          32
# 2  Port Lincoln      AU -34.7333  135.8667     61.03        67          76
# 3  Punta Arenas      CL -53.1500  -70.9167     46.51        76          75
# 4    Chokurdakh      RU  70.6333  147.9167     13.59        92         100
#
#    Wind Speed Current Description
# 0       12.15          light rain
# 1        4.09    scattered clouds
# 2       15.43       broken clouds
# 3        4.61          light rain
# 4        5.77     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV.
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
